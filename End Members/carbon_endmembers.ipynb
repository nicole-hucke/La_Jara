# %% [markdown]
# ## Carbon end members for individual storms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
import seaborn as sns
from pathlib import Path
import matplotlib.cm as cm

# importing data
data = pd.read_csv('endmembers_data.csv')
storm2 = pd.read_csv('storm_csvs/st2.csv')
storm3 = pd.read_csv('storm_csvs/st3.csv')
storm4_down = pd.read_csv('storm_csvs/st4_down.csv')
storm4_up = pd.read_csv('storm_csvs/st4_up.csv')
storm5_down = pd.read_csv('storm_csvs/st5_down.csv')
storm5_up = pd.read_csv('storm_csvs/st5_up.csv')
storm6 = pd.read_csv('storm_csvs/st6.csv')
storm7_down = pd.read_csv('storm_csvs/st7_down.csv')
storm7_up = pd.read_csv('storm_csvs/st7_up.csv')

# %% [markdown]
# Function for delineating areas of each source signature

# %%
def plot_convex_hull(points, ax, color, alpha=0.2):
    hull = ConvexHull(points)
    for simplex in hull.simplices:
        ax.plot(points[simplex, 0], points[simplex, 1], '--', color=color)
    # Fill the convex hull
    ax.fill(points[hull.vertices, 0], points[hull.vertices, 1], color=color, alpha=alpha)

# %% [markdown]
# ## Plotting end members

# %% [markdown]
# Storm 2 - Aug 3th 2022

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm2['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm2['Source'].unique()):
    subset = storm2[storm2['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
    
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 2 (8/3/2022) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm2.png')
plt.show()

# %% [markdown]
# Storm 3 - Aug 8th 2022

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm3['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm3['Source'].unique()):
    subset = storm3[storm3['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
    
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')

# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 3 (8/8/2022) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm3.png')
plt.show()

# %% [markdown]
# Storm 4 - July 29 2023

# %%
# DOWNSTREAM STORM 4
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm4_down['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm4_down['Source'].unique()):
    subset = storm4_down[storm4_down['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 4 Downstream (7/29/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm4_down.png')
plt.show()

# %%
# UPSTREAM STORM 4
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm4_up['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm4_up['Source'].unique()):
    subset = storm4_up[storm4_up['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
    
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 4 Upstream (7/29/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm4_up.png')
plt.show()

# %% [markdown]
# Storm 5 - 8/13/2023

# %%
# DOWNSTREAM STORM 5
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm5_down['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm5_down['Source'].unique()):
    subset = storm5_down[storm5_down['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
    
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 5 Downstream (8/13/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm5_down.png')
plt.show()

# %%
# UPSTREAM STORM 5
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm5_up['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm5_up['Source'].unique()):
    subset = storm5_up[storm5_up['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
    
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 5 Upstream (8/13/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm5_up.png')
plt.show()

# %% [markdown]
# Storm 6 - 8/28/2023

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm6['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm6['Source'].unique()):
    subset = storm6[storm6['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
        
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 6 (8/28/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm6.png')
plt.show()

# %% [markdown]
# Storm 7 - 9/14/2023

# %%
# DOWNSTREAM STORM 7
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm7_down['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm7_down['Source'].unique()):
    subset = storm7_down[storm7_down['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
        
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 7 Downstream (9/14/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm7_down.png')
plt.show()

# %%
# UPSTREAM STORM 4
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = storm7_up['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(storm7_up['Source'].unique()):
    subset = storm7_up[storm7_up['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples
        
    # Annotate the points with the "hydrograph" data
    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')


# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Storm 7 Upstream (9/14/2023) - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_storm7_up.png')
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27284\2264629127.py:43: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = fig.colorbar(sm, ax=ax)

# %% [markdown]
# ### Spring 2023

# %%
spring = pd.read_csv('storm_csvs/spring.csv')

sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 9))

# Scatter plot for each source with different markers and colors
markers = ['o', 's', 'D', '^', 'v', '*']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker=markers[i], color=colors[i])

# Using the delineating function  
for i, source in enumerate(data['Source'].unique()):
    subset = data[data['Source'] == source]
    points = np.array(subset[['%C', 'd13C']])
    plot_convex_hull(points, ax, colors[i], alpha=0.2)

# Scatter plot for the water samples with gradient colors based on 'order'
cmap = cm.get_cmap('copper')  # Use a grayscale colormap
orders = spring['order']
norm = plt.Normalize(orders.min(), orders.max())
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

for i, source in enumerate(spring['Source'].unique()):
    subset = spring[spring['Source'] == source]
    colors = cmap(norm(subset['order']))
    ax.plot(subset['%C'], subset['d13C'], color='sienna', linestyle=':', linewidth=2) # connecting lines
    ax.scatter(subset['%C'], subset['d13C'], label=source, s=100, marker='^', color=colors) # actual samples

    for j, row in subset.iterrows():
        ax.annotate(row['hydrograph'], (row['%C'], row['d13C']), textcoords="offset points", xytext=(0,10), ha='center')

# Label the axes
ax.set_xlabel('%C')
ax.set_ylabel('δ13C (‰)')
ax.set_title('Spring Snowmelt - %C vs δ13C')
ax.legend(loc='best', frameon=True)

# Add a colorbar to show the gradient
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Sample Order')

# Ensure the 'plots' directory exists
plots_dir = Path('plots_storms')
plots_dir.mkdir(parents=True, exist_ok=True)

# Save the figure
plt.savefig(plots_dir / 'carbon_endmembers_spring.png')
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_27284\1444031095.py:42: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = fig.colorbar(sm, ax=ax)
