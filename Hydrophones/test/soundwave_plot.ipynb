# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load the FLAC audio file
file_path = "test_audio2.flac"
audio, sr = librosa.load(file_path, sr=None, mono=False)

# Separate the left and right channels
left_channel = audio[0]
right_channel = audio[1]

fig, axs = plt.subplots(2, 1, figsize=(15, 8))  # 2 rows, 1 column, figure size 10x8

# Plot the left channel in the first subplot
librosa.display.waveshow(left_channel, sr=sr, ax=axs[0])
axs[0].set_title('Left Gain Soundwave')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Amplitude')

# Plot the right channel in the second subplot
librosa.display.waveshow(right_channel, sr=sr, ax=axs[1])
axs[1].set_title('Right Gain Soundwave')
axs[1].set_xlabel('Time (s)')
axs[1].set_ylabel('Amplitude')

plt.tight_layout()  # Ensure subplots don't overlap
plt.savefig('ejemplo_angel.png', dpi=300)
plt.show()

# %% [markdown]
# ### Hydrophone

# %% [markdown]
# Low Flow Example

# %%
# Load the FLAC audio file
file_path = "baseflow/raspberrypi_080322-000100.flac"
audio, sr = librosa.load(file_path, sr=None, mono=False)

# Separate the left and right channels
left_channel = audio[0]
right_channel = audio[1]
low_flow_example = right_channel

plt.figure(figsize=(5, 3))
# plot the right channel in the second subplot
librosa.display.waveshow(right_channel, sr=sr, color='mediumseagreen')
plt.title('(1) Low Flow Soundwave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.ylim(-0.01, 0.01)  # Adjust y-axis limits to zoom in on low flow

plt.tight_layout()  # Ensure subplots don't overlap
plt.show()

# %% [markdown]
# High Flow Example

# %%
# Load the FLAC audio file
file_path = "storm2/raspberrypi_080322-143100.flac"
audio, sr = librosa.load(file_path, sr=None, mono=False)

# Separate the left and right channels
left_channel = audio[0]
right_channel = audio[1]
low_flow_example = right_channel

plt.figure(figsize=(5, 3))
# plot the right channel in the second subplot
librosa.display.waveshow(right_channel, sr=sr, color='mediumseagreen')
plt.title('(2) High Flow Soundwave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.ylim(-0.01, 0.01)  # Adjust y-axis limits to zoom in on low flow

plt.tight_layout()  # Ensure subplots don't overlap
plt.show()

# %% [markdown]
# Hydrograph

# %%
import pandas as pd

discharge = pd.read_csv("discharge_2022.csv", parse_dates=['Date_Time'], index_col='Date_Time')

# %%
event_start = pd.to_datetime("2022-08-03 12:31")
event_end = pd.to_datetime("2022-08-03 19:31")
event_data = discharge.loc[event_start:event_end]

plt.figure(figsize=(5, 4))
plt.plot(event_data.index, event_data['Q'], color='royalblue', linewidth=3)
plt.title('Discharge Hydrograph During Event')
plt.xlabel('Time')
plt.ylabel('Discharge (m³/s)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### JPM

# %% [markdown]
# Low Flow Example

# %%
# Load the FLAC audio file
file_path = "storm2/raspberrypi_080322-130100.flac"
audio, sr = librosa.load(file_path, sr=None, mono=False)

# Separate the left and right channels
left_channel = audio[0]
right_channel = audio[1]
low_flow_example = left_channel

plt.figure(figsize=(7, 3))
# plot the right channel in the second subplot
librosa.display.waveshow(left_channel, sr=sr, color='mediumseagreen')
plt.title('(1) Low Flow Soundwave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.ylim(-0.5, 0.5)  # Adjust y-axis limits to zoom in on low flow

plt.tight_layout()  # Ensure subplots don't overlap
plt.show()

# %% [markdown]
# High Flow Example

# %%
# Load the FLAC audio file
file_path = "storm2/raspberrypi_080322-150100.flac"
audio, sr = librosa.load(file_path, sr=None, mono=False)

# Separate the left and right channels
left_channel = audio[0]
right_channel = audio[1]
low_flow_example = right_channel

plt.figure(figsize=(7, 3))
# plot the right channel in the second subplot
librosa.display.waveshow(left_channel, sr=sr, color='mediumseagreen')
plt.title('(2) High Flow Soundwave')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.ylim(-0.5, 0.5)  # Adjust y-axis limits to zoom in on low flow

plt.tight_layout()  # Ensure subplots don't overlap
plt.show()
