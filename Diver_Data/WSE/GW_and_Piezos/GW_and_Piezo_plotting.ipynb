# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter

directory = 'C:/Users/huck4481/Documents/GitHub/La_Jara/Diver_Data/WSE/GW_and_Piezos/data'
WSE_dict = {}

for filename in os.listdir(directory): # iterate over all files in GW_and_Piezos folder
    if filename.endswith('.csv'): # checking if its a csv
        # construct the full file path
        file_path = os.path.join(directory, filename)
        df = pd.read_csv(file_path)
        df['Date_Time'] = pd.to_datetime(df['Date_Time'])
        # remove the '.csv' from the filename to use as the dictionary key
        key = filename[:-4]
        # store the data frame in the dictionary
        WSE_dict[key] = df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       7
#       8 directory = 'C:/Users/huck4481/Documents/GitHub/La_Jara/Diver_Data/WSE/GW_and_Piezos/data'
#       9 WSE_dict = {}
#      10
# ---> 11 for filename in os.listdir(directory): # iterate over all files in GW_and_Piezos folder
#      12     if filename.endswith('.csv'): # checking if its a csv
#      13         # construct the full file path
#      14         file_path = os.path.join(directory, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/huck4481/Documents/GitHub/La_Jara/Diver_Data/WSE/GW_and_Piezos/data'

# %% [markdown]
# ### 2021 Plots:

# %% [markdown]
# Downstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 9), sharex=True, facecolor='white')

# Plot for Location at P1
sns.lineplot(data=WSE_dict['GW_down_left_2021'], x='Date_Time', y='P1', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_down_right_2021'], x='Date_Time', y='P1', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P1C_21_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 1')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P2
sns.lineplot(data=WSE_dict['GW_down_left_2021'], x='Date_Time', y='P2', color='#555555', linestyle='-', ax=axes[1])
sns.lineplot(data=WSE_dict['GW_down_right_2021'], x='Date_Time', y='P2', color='gray', linestyle=':', ax=axes[1])
sns.lineplot(data=WSE_dict['P2C_21_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[1])
axes[1].set_title('Water Elevations at Piezometer 2')
axes[1].set_ylabel('Elevation (m)')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P3
sns.lineplot(data=WSE_dict['GW_down_left_2021'], x='Date_Time', y='P3', label='Left GWE', color='#555555', linestyle='-', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['GW_down_right_2021'], x='Date_Time', y='P3', label='Right GWE', color='gray', linestyle=':', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['P3C_21_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[2], legend=False)
axes[2].set_title('Water Elevations at Piezometer 3')
axes[2].set_ylabel('Elevation (m)')
axes[2].set_xlabel('Time')
axes[2].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Downstream 2021', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_down_2021.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Upstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 6), sharex=True, facecolor='white')

# Plot for Location at P4
sns.lineplot(data=WSE_dict['GW_up_left_2021'], x='Date_Time', y='P4', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_up_right_2021'], x='Date_Time', y='P4', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P4C_21_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 4')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P6
sns.lineplot(data=WSE_dict['GW_up_left_2021'], x='Date_Time', y='P6', label='Left GWE', color='#555555', linestyle='-', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['GW_up_right_2021'], x='Date_Time', y='P6', label='Right GWE', color='gray', linestyle=':', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['P6C_21_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[1], legend=False)
axes[1].set_title('Water Elevations at Piezometer 6')
axes[1].set_ylabel('Elevation (m)')
axes[1].set_xlabel('Time')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Upstream 2021', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_up_2021.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 2022 Plots:

# %% [markdown]
# Downstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 9), sharex=True, facecolor='white')

# Plot for Location at P1
sns.lineplot(data=WSE_dict['GW_down_left_2022'], x='Date_Time', y='P1', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_down_right_2022'], x='Date_Time', y='P1', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P1C_22_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 1')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P2
sns.lineplot(data=WSE_dict['GW_down_left_2022'], x='Date_Time', y='P2', color='#555555', linestyle='-', ax=axes[1])
sns.lineplot(data=WSE_dict['GW_down_right_2022'], x='Date_Time', y='P2', color='gray', linestyle=':', ax=axes[1])
sns.lineplot(data=WSE_dict['P2C_22_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[1])
axes[1].set_title('Water Elevations at Piezometer 2')
axes[1].set_ylabel('Elevation (m)')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P3
sns.lineplot(data=WSE_dict['GW_down_left_2022'], x='Date_Time', y='P3', label='Left GWE', color='#555555', linestyle='-', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['GW_down_right_2022'], x='Date_Time', y='P3', label='Right GWE', color='gray', linestyle=':', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['P3C_22_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[2], legend=False)
axes[2].set_title('Water Elevations at Piezometer 3')
axes[2].set_ylabel('Elevation (m)')
axes[2].set_xlabel('Time')
axes[2].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Downstream 2022', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_down_2022.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Upstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 6), sharex=True, facecolor='white')

# Plot for Location at P4
sns.lineplot(data=WSE_dict['GW_up_left_2022'], x='Date_Time', y='P4', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_up_right_2022'], x='Date_Time', y='P4', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P4C_22_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 4')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P6
sns.lineplot(data=WSE_dict['GW_up_left_2022'], x='Date_Time', y='P6', label='Left GWE', color='#555555', linestyle='-', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['GW_up_right_2022'], x='Date_Time', y='P6', label='Right GWE', color='gray', linestyle=':', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['P6C_22_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[1], legend=False)
axes[1].set_title('Water Elevations at Piezometer 6')
axes[1].set_ylabel('Elevation (m)')
axes[1].set_xlabel('Time')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Upstream 2022', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_up_2022.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 2023 Plots

# %% [markdown]
# Downstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 9), sharex=True, facecolor='white')

# Plot for Location at P1
sns.lineplot(data=WSE_dict['GW_down_left_2023'], x='Date_Time', y='P1', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_down_right_2023'], x='Date_Time', y='P1', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P1C_23_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 1')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P2
sns.lineplot(data=WSE_dict['GW_down_left_2023'], x='Date_Time', y='P2', color='#555555', linestyle='-', ax=axes[1])
sns.lineplot(data=WSE_dict['GW_down_right_2023'], x='Date_Time', y='P2', color='gray', linestyle=':', ax=axes[1])
sns.lineplot(data=WSE_dict['P2C_23_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[1])
axes[1].set_title('Water Elevations at Piezometer 2')
axes[1].set_ylabel('Elevation (m)')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P3
sns.lineplot(data=WSE_dict['GW_down_left_2023'], x='Date_Time', y='P3', label='Left GWE', color='#555555', linestyle='-', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['GW_down_right_2023'], x='Date_Time', y='P3', label='Right GWE', color='gray', linestyle=':', ax=axes[2], legend=False)
sns.lineplot(data=WSE_dict['P3C_23_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[2], legend=False)
axes[2].set_title('Water Elevations at Piezometer 3')
axes[2].set_ylabel('Elevation (m)')
axes[2].set_xlabel('Time')
axes[2].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Downstream 2023', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_down_2023.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Upstream

# %%
# Set Seaborn style
sns.set_theme(style="whitegrid", palette="pastel")

# Create subplots with a white background
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 6), sharex=True, facecolor='white')

# Plot for Location at P4
sns.lineplot(data=WSE_dict['GW_up_left_2023'], x='Date_Time', y='P4', color='#555555', linestyle='-', ax=axes[0])
sns.lineplot(data=WSE_dict['GW_up_right_2023'], x='Date_Time', y='P4', color='gray', linestyle=':', ax=axes[0])
sns.lineplot(data=WSE_dict['P4C_23_WSE'], x='Date_Time', y='WSE', color='blue', ax=axes[0])
axes[0].set_title('Water Elevations at Piezometer 4')
axes[0].set_ylabel('Elevation (m)')
axes[0].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Plot for Location at P6
sns.lineplot(data=WSE_dict['GW_up_left_2023'], x='Date_Time', y='P6', label='Left GWE', color='#555555', linestyle='-', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['GW_up_right_2023'], x='Date_Time', y='P6', label='Right GWE', color='gray', linestyle=':', ax=axes[1], legend=False)
sns.lineplot(data=WSE_dict['P6C_23_WSE'], x='Date_Time', y='WSE', label='Water Surface', color='blue', ax=axes[1], legend=False)
axes[1].set_title('Water Elevations at Piezometer 6')
axes[1].set_ylabel('Elevation (m)')
axes[1].set_xlabel('Time')
axes[1].yaxis.set_major_formatter(StrMethodFormatter('{x:,.1f}')) 

# Adjust layout
plt.tight_layout()
fig.suptitle('Piezometer and Ground Water Elevations - Upstream 2023', fontsize=16, y=1.02)
fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.04), fancybox=True, shadow=True, ncol=3)
plt.savefig('GW_piezo_up_2023.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Calculate hydraulic head (groundwater WSE - piezometer WSE)

# %%
# For each piezometer, calculate VHG in each year
# VHG = groundwater WSE - piezometer WSE

vhg_results = {}
year_config = {
    2021: {
        "down": {
            "gw_left": "GW_down_left_2021",
            "gw_right": "GW_down_right_2021",
            "piezos": ["P1", "P2", "P3"],
            "piezo_suffix": "2021",
        },
        "up": {
            "gw_left": "GW_up_left_2021",
            "gw_right": "GW_up_right_2021",
            "piezos": ["P4", "P6"],
            "piezo_suffix": "2021",
        },
    },
    2022: {
        "down": {
            "gw_left": "GW_down_left_2022",
            "gw_right": "GW_down_right_2022",
            "piezos": ["P1", "P2", "P3"],
            "piezo_suffix": "2022",
        },
        "up": {
            "gw_left": "GW_up_left_2022",
            "gw_right": "GW_up_right_2022",
            "piezos": ["P4", "P6"],
            "piezo_suffix": "2022",
        },
    },
    2023: {
        "down": {
            "gw_left": "GW_down_left_2023",
            "gw_right": "GW_down_right_2023",
            "piezos": ["P1", "P2", "P3"],
            "piezo_suffix": "2023",
        },
        "up": {
            "gw_left": "GW_up_left_2023",
            "gw_right": "GW_up_right_2023",
            "piezos": ["P4", "P6"],
            "piezo_suffix": "2023",
        },
    },
}
for year, banks in year_config.items():
    for bank, cfg in banks.items():
        gw_left = WSE_dict[cfg["gw_left"]][["Date_Time"] + cfg["piezos"]].rename(
            columns={p: f"{p}_gw_left" for p in cfg["piezos"]}
        )
        gw_right = WSE_dict[cfg["gw_right"]][["Date_Time"] + cfg["piezos"]].rename(
            columns={p: f"{p}_gw_right" for p in cfg["piezos"]}
        )

        for piezo in cfg["piezos"]:
            piezo_key = f"{piezo}C_{cfg['piezo_suffix'][-2:]}_WSE"
            piezo_df = WSE_dict[piezo_key][["Date_Time", "WSE"]].rename(columns={"WSE": f"{piezo}_WSE"})

            merged = (
                piezo_df.merge(gw_left[["Date_Time", f"{piezo}_gw_left"]], on="Date_Time", how="inner")
                        .merge(gw_right[["Date_Time", f"{piezo}_gw_right"]], on="Date_Time", how="inner")
            )

            merged[f"{piezo}_h_left"] = merged[f"{piezo}_gw_left"] - merged[f"{piezo}_WSE"]
            merged[f"{piezo}_h_right"] = merged[f"{piezo}_gw_right"] - merged[f"{piezo}_WSE"]
            merged[f"{piezo}_h_average"] = merged[[f"{piezo}_h_left", f"{piezo}_h_right"]].mean(axis=1)

            vhg_results[f"{piezo}_{bank}_{year}"] = merged[[
                "Date_Time",
                f"{piezo}_WSE",
                f"{piezo}_gw_left",
                f"{piezo}_gw_right",
                f"{piezo}_h_left",
                f"{piezo}_h_right",
                f"{piezo}_h_average"
            ]]

vhg_results["P1_down_2021"].head()
# Out:
#             Date_Time       P1_WSE   P1_gw_left  P1_gw_right  P1_h_left  \
# 0 2021-08-12 00:00:00  2721.843053  2721.299569  2721.131428  -0.543484
# 1 2021-08-12 00:15:00  2721.843822  2721.299759  2721.132921  -0.544063
# 2 2021-08-12 00:30:00  2721.844212  2721.296058  2721.129207  -0.548154
# 3 2021-08-12 00:45:00  2721.843242  2721.299311  2721.132447  -0.543931
# 4 2021-08-12 01:00:00  2721.842076  2721.294182  2721.130106  -0.547894
#
#    P1_h_right  P1_h_average
# 0   -0.711625     -0.627555
# 1   -0.710901     -0.627482
# 2   -0.715005     -0.631580
# 3   -0.710795     -0.627363
# 4   -0.711970     -0.629932

# %%
# export data as csv files
output_dir = 'C:/Users/huck4481/Documents/GitHub/La_Jara/Diver_Data/WSE/GW_and_Piezos/results'
for key, df in vhg_results.items():
    output_path = os.path.join(output_dir, f"{key}_hydraulic_head.csv")
    df.to_csv(output_path, index=False)

# %% [markdown]
# Calculating seasonal averages

# %%
# only keep VHF averages for each piezometer: 
full_2023 = pd.DataFrame()
for key, df in vhg_results.items():
    if "2023" in key:
        piezo = key.split("_")[0]
        bank = key.split("_")[1]
        df_subset = df[["Date_Time", f"{piezo}_h_left", f"{piezo}_h_right", f"{piezo}_h_average"]]
        if full_2023.empty:
            full_2023 = df_subset
        else:
            full_2023 = full_2023.merge(df_subset, on="Date_Time", how="outer")

full_2023
# Out:
#                 Date_Time  P1_h_left  P1_h_right  P1_h_average  P2_h_left  \
# 0     2023-03-02 00:00:00  -0.573134   -0.949298     -0.761216  -0.743964
# 1     2023-03-02 00:15:00  -0.575664   -0.950927     -0.763296  -0.739534
# 2     2023-03-02 00:30:00  -0.575664   -0.950219     -0.762941  -0.739534
# 3     2023-03-02 00:45:00  -0.579163   -0.951969     -0.765566  -0.741283
# 4     2023-03-02 01:00:00  -0.578135   -0.952451     -0.765293  -0.740537
# ...                   ...        ...         ...           ...        ...
# 13447 2023-09-17 22:00:00  -0.284934   -0.948572     -0.616753  -0.797973
# 13448 2023-09-17 22:30:00        NaN         NaN           NaN        NaN
# 13449 2023-09-17 22:45:00  -0.286756   -0.951738     -0.619247  -0.795446
# 13450 2023-09-17 23:15:00        NaN         NaN           NaN        NaN
# 13451 2023-09-17 23:30:00  -0.283184   -0.948572     -0.615878  -0.796222
#
#        P2_h_right  P2_h_average  P3_h_left  P3_h_right  P3_h_average  \
# 0       -0.287896     -0.515930        NaN         NaN           NaN
# 1       -0.286632     -0.513083        NaN         NaN           NaN
# 2       -0.287649     -0.513592        NaN         NaN           NaN
# 3       -0.287649     -0.514466        NaN         NaN           NaN
# 4       -0.288139     -0.514338        NaN         NaN           NaN
# ...           ...           ...        ...         ...           ...
# 13447   -0.300821     -0.549397  -1.462942   -0.191931     -0.827436
# 13448         NaN           NaN        NaN         NaN           NaN
# 13449   -0.300538     -0.547992  -1.457516   -0.189347     -0.823431
# 13450         NaN           NaN        NaN         NaN           NaN
# 13451   -0.300820     -0.548521  -1.461192   -0.191931     -0.826561
#
#        P4_h_left  P4_h_right  P4_h_average  P6_h_left  P6_h_right  \
# 0      -0.415169   -0.353609     -0.384389  -0.619742   -0.429896
# 1      -0.414410   -0.351860     -0.383135  -0.617911   -0.429896
# 2      -0.413690   -0.355359     -0.384524  -0.619563   -0.428727
# 3      -0.413421   -0.354906     -0.384164  -0.618571   -0.427874
# 4      -0.414098   -0.355646     -0.384872  -0.617151   -0.426407
# ...          ...         ...           ...        ...         ...
# 13447        NaN         NaN           NaN  -0.619239   -0.390615
# 13448        NaN         NaN           NaN  -0.619998   -0.394968
# 13449        NaN         NaN           NaN        NaN         NaN
# 13450        NaN         NaN           NaN  -0.618249   -0.391795
# 13451        NaN         NaN           NaN  -0.618246   -0.394396
#
#        P6_h_average
# 0         -0.524819
# 1         -0.523904
# 2         -0.524145
# 3         -0.523222
# 4         -0.521779
# ...             ...
# 13447     -0.504927
# 13448     -0.507483
# 13449           NaN
# 13450     -0.505022
# 13451     -0.506321
#
# [13452 rows x 16 columns]

# %%
# separate 2023 data into seasons to calculate averages
spring_2023 = full_2023[(full_2023["Date_Time"] >= "2023-03-01") & (full_2023["Date_Time"] < "2023-06-19")]
summer_2023 = full_2023[(full_2023["Date_Time"] >= "2023-06-19") & (full_2023["Date_Time"] < "2023-09-21")]
# export as csv files
spring_2023.to_csv(os.path.join(output_dir, "spring_2023_hydraulic_head.csv"), index=False)
summer_2023.to_csv(os.path.join(output_dir, "summer_2023_hydraulic_head.csv"), index=False)

# %%
# spring min, max and average
spring_stats = spring_2023.describe().loc[["min", "max", "mean"]]
spring_stats.to_csv(os.path.join(output_dir, "spring_2023_summary.csv"))
# summer min, max and average
summer_stats = summer_2023.describe().loc[["min", "max", "mean"]]
summer_stats.to_csv(os.path.join(output_dir, "summer_2023_summary.csv"))

# %%
summer_stats
# Out:
#                           Date_Time  P1_h_left  P1_h_right  P1_h_average  \
# min             2023-06-19 00:15:00  -0.496245   -1.016454     -0.976946
# max             2023-09-17 23:30:00  -0.264949   -0.869752     -0.580548
# mean  2023-08-05 16:57:51.879033856  -0.385338   -0.966831     -0.676210
#
#       P2_h_left  P2_h_right  P2_h_average  P3_h_left  P3_h_right  \
# min   -0.831703   -0.337988     -0.570522  -1.496518   -0.257965
# max   -0.776269   -0.224894     -0.237355  -1.311744   -0.104016
# mean  -0.803715   -0.290147     -0.546810  -1.410376   -0.166788
#
#       P3_h_average  P4_h_left  P4_h_right  P4_h_average  P6_h_left  \
# min      -1.419627  -0.386132   -0.436673     -0.410570  -0.634691
# max      -0.141959  -0.353138   -0.260427     -0.308964  -0.525556
# mean     -0.788302  -0.366682   -0.381162     -0.373922  -0.597202
#
#       P6_h_right  P6_h_average
# min    -0.437170     -0.522576
# max    -0.364348     -0.452753
# mean   -0.402979     -0.500091

# %%
spring_stats
# Out:
#                           Date_Time  P1_h_left  P1_h_right  P1_h_average  \
# min             2023-03-02 00:00:00  -0.677879   -0.971977     -0.797081
# max             2023-06-18 23:45:00  -0.071467   -0.239311     -0.112930
# mean  2023-04-26 12:58:08.578901504  -0.318023   -0.651303     -0.484624
#
#       P2_h_left  P2_h_right  P2_h_average  P3_h_left  P3_h_right  \
# min   -0.839620   -0.310096     -0.560675  -1.523909   -0.217496
# max   -0.352026    0.071119     -0.161458  -0.892075   -0.040517
# mean  -0.691217   -0.137269     -0.414208  -1.328310   -0.131631
#
#       P3_h_average  P4_h_left  P4_h_right  P4_h_average  P6_h_left  \
# min      -1.480736  -0.508796   -0.379275     -0.423425  -0.649675
# max      -0.492135   0.108588   -0.193320     -0.082043  -0.259962
# mean     -0.730384  -0.375050   -0.264303     -0.319677  -0.486057
#
#       P6_h_right  P6_h_average
# min    -0.546160     -0.551742
# max    -0.375205     -0.335112
# mean   -0.447901     -0.466963
