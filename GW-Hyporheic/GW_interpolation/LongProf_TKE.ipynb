# %% [markdown]
# ## This is just to plot the long profile and the TKE values at each location

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from matplotlib import ticker
from tqdm import tqdm

# load the topography data
down_reach = pd.read_csv('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/downreach_longprofile.csv')
up_reach = pd.read_csv('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/upreach_longprofile.csv')

temprobes = pd.DataFrame({ #the order is TP1 thru TP8
    'Distance': [13, 23, 41, 50, 10.15, 14.6, 31.4, 56.6],
    'Elevation': [2722.652, 2723.389, 2724.88, 2725.338, 2733.665, 2733.998, 2735.669, 2738.474]  
})

# %% [markdown]
# ### Plotting for Spring 2023 - Downstream Reach

# %%
fig, ax = plt.subplots(figsize=(20, 9))
fig.patch.set_facecolor('white')  # set the figure's facecolor to white
ax.plot(down_reach.iloc[:, 0], down_reach.iloc[:, 1], label='Thalweg', color = 'black')

# add in temperature probes
# TP1
plt.vlines(temprobes.iloc[0,0], temprobes.iloc[0,1]-1, temprobes.iloc[0,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1], 'TP1', ha='center', va='bottom')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.5, 'A = 0.2178', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.4, 'B = 0.2097', ha='center', va='bottom')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.3, 'C = 0.2142', ha='center', va='bottom')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.2, 'D = 0.1591', ha='center', va='bottom')
# TP2
plt.vlines(temprobes.iloc[1,0], temprobes.iloc[1,1]-1, temprobes.iloc[1,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1], 'TP2', ha='center', va='bottom')
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1] + 0.3, 'A = 0.4293', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1] + 0.2, 'B = 0.8406', ha='center', va='bottom')

# TP3
plt.vlines(temprobes.iloc[2,0], temprobes.iloc[2,1]-1, temprobes.iloc[2,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1], 'TP3', ha='center', va='bottom')
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1] + 0.3, 'C = 0.4902', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1] + 0.2, 'D = 0.4677', ha='center', va='bottom')

# Set the limits of the y-axis
ax.set_ylim(2721, 2726.5)
# Add labels and title
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Downstream Long Profile and TKE values - Spring 2023')
ax.legend()
plt.savefig('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/SP23_Down_LongProfile_TKE.png')

# Show the plot
plt.show()

# %% [markdown]
# ### Plotting for Spring 2023 - Upstream Reach

# %%
# Plot the upstream reach
fig, ax = plt.subplots(figsize=(20, 9))
fig.patch.set_facecolor('white')  # set the figure's facecolor to white
ax.plot(up_reach.iloc[:, 0], up_reach.iloc[:, 1], label='Thalweg', color = 'black')

# add in temperature probes
# TP5
plt.vlines(temprobes.iloc[4,0], temprobes.iloc[4,1]-1, temprobes.iloc[4,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1], 'TP5', ha='center', va='bottom')
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1] + 0.5, 'A & B = 0.3039', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1] + 0.3, 'C & D = 0.3344', ha='center', va='bottom')
# TP6
plt.vlines(temprobes.iloc[5,0], temprobes.iloc[5,1]-1, temprobes.iloc[5,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1], 'TP6', ha='center', va='bottom')
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1] + 0.5, 'A & B = 0.8108', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1] + 0.3, 'C & D = 0.6117', ha='center', va='bottom')
# TP7
plt.vlines(temprobes.iloc[6,0], temprobes.iloc[6,1]-1, temprobes.iloc[6,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1], 'TP7', ha='center', va='bottom')
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1] + 0.5, 'A & B = 0.2585', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1] + 0.3, 'C & D = 0.2554', ha='center', va='bottom')
# TP8
plt.vlines(temprobes.iloc[7,0], temprobes.iloc[7,1]-1, temprobes.iloc[7,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1], 'TP8', ha='center', va='bottom')
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1] + 0.5, 'A = 0.4042', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1] + 0.3, 'C & D = 0.4731', ha='center', va='bottom')

# Set the limits of the y-axis
ax.set_ylim(2732, 2740)
# Add labels and title

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Upstream Long Profile and TKE values - Spring 2023')
ax.legend()
plt.savefig('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/SP23_Up_LongProfile_TKE.png')

# Show the plot
plt.show()

# %% [markdown]
# ### Plotting for Summer 2023 - Downstream Reach

# %%
fig, ax = plt.subplots(figsize=(20, 9))
fig.patch.set_facecolor('white')  # set the figure's facecolor to white
ax.plot(down_reach.iloc[:, 0], down_reach.iloc[:, 1], label='Thalweg', color = 'black')

# add in temperature probes
# TP1
plt.vlines(temprobes.iloc[0,0], temprobes.iloc[0,1]-1, temprobes.iloc[0,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1], 'TP1', ha='center', va='bottom')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.3, 'A & B = 0.176', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1] + 0.2, 'C & D = 0.598', ha='center', va='bottom')
# TP2
plt.vlines(temprobes.iloc[1,0], temprobes.iloc[1,1]-1, temprobes.iloc[1,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1], 'TP2', ha='center', va='bottom')
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1] + 0.2, 'A & B = 0.722', ha='center', va='bottom')  # add TKE value
# TP3
plt.vlines(temprobes.iloc[2,0], temprobes.iloc[2,1]-1, temprobes.iloc[2,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1], 'TP3', ha='center', va='bottom')
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1] + 0.2, 'C & D= 0.335', ha='center', va='bottom')  # add TKE value

# Set the limits of the y-axis
ax.set_ylim(2721, 2726.5)
# Add labels and title
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Downstream Long Profile and TKE values - Summer 2023')
ax.legend()
plt.savefig('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/SM23_Down_LongProfile_TKE.png')

# Show the plot
plt.show()

# %% [markdown]
# ### Plotting for Summer 2023 - Upstream Reach

# %%
# Plot the upstream reach
fig, ax = plt.subplots(figsize=(20, 9))
fig.patch.set_facecolor('white')  # set the figure's facecolor to white
ax.plot(up_reach.iloc[:, 0], up_reach.iloc[:, 1], label='Thalweg', color = 'black')

# add in temperature probes
# TP5
plt.vlines(temprobes.iloc[4,0], temprobes.iloc[4,1]-1, temprobes.iloc[4,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1], 'TP5', ha='center', va='bottom')
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1] + 0.5, 'A & B = 0.153', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1] + 0.3, 'C & D = 0.153', ha='center', va='bottom')
# TP6
plt.vlines(temprobes.iloc[5,0], temprobes.iloc[5,1]-1, temprobes.iloc[5,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1], 'TP6', ha='center', va='bottom')
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1] + 0.5, 'A & B = 0.146', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1] + 0.3, 'C & D = 0.100', ha='center', va='bottom')
# TP7
plt.vlines(temprobes.iloc[6,0], temprobes.iloc[6,1]-1, temprobes.iloc[6,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1], 'TP7', ha='center', va='bottom')
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1] + 0.5, 'A & B = 0.222', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1] + 0.3, 'C & D = 0.173', ha='center', va='bottom')
# TP8
plt.vlines(temprobes.iloc[7,0], temprobes.iloc[7,1]-1, temprobes.iloc[7,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1], 'TP8', ha='center', va='bottom')
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1] + 0.5, 'A = 0.234', ha='center', va='bottom')  # add TKE value
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1] + 0.3, 'C & D = 0.0.114', ha='center', va='bottom')

# Set the limits of the y-axis
ax.set_ylim(2732, 2740)
# Add labels and title

ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Upstream Long Profile and TKE values - Summer 2023')
ax.legend()
plt.savefig('C:/Users/huck4481/Documents/GitHub/La_Jara/GW-Hyporheic/SM23_Up_LongProfile_TKE.png')

# Show the plot
plt.show()
