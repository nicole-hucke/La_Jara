# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from matplotlib import ticker
from tqdm import tqdm

# load the topography data
down_reach = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/downreach_longprofile.csv')
up_reach = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/upreach_longprofile.csv')

# load the groundwater data (summer 2021)
GW13_SM21 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW1_3_SM21.csv')
GW24_SM21 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW2_4_SM21.csv')
GW68_SM21 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW6_8_SM21.csv')
GW79_SM21 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW7_9_SM21.csv')

# load the groundwater data (summer 2022)
GW13_SM22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW1_3_SM22.csv')
GW24_SM22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW2_4_SM22.csv')
GW68_SM22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW6_8_SM22.csv')
GW79_SM22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW7_9_SM22.csv')

# load the groundwater data (summer 2023)
GW13_SM23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW1_3_SM23.csv')
GW24_SM23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW2_4_SM23.csv')
GW68_SM23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW6_8_SM23.csv')
GW79_SM23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW7_9_SM23.csv')

# load the groundwater data (spring 2022)
GW13_SP22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW1_3_SP22.csv')
GW24_SP22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW2_4_SP22.csv')
GW68_SP22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW6_8_SP22.csv')
GW79_SP22 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW7_9_SP22.csv')

# load the groundwater data (spring 2023)
GW13_SP23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW1_3_SP23.csv')
GW24_SP23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW2_4_SP23.csv')
GW68_SP23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW6_8_SP23.csv')
GW79_SP23 = pd.read_csv('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/GW7_9_SP23.csv')

wells = pd.DataFrame({ #the order for these is GW1 to GW9
    'Distance': [3.1, 8.5, 17, 29.5, 0, 18, 17.2, 36.2, 36.9],
    'Elevation': [2722.372, 2722.683, 2723.117, 2724.179, 2733.515, 2734.527, 2734.794, 2736.657, 2736.795]  
})
piezometers = pd.DataFrame({ #the order for these is P1 to P6 (sll stilling wells)
    'Distance': [0, 20.7, 34.5, 2.6, 35.8, 46.5],
    'Elevation': [2722.252, 2723.504, 2724.714, 2733.45, 2736.765, 2737.747]
})
temprobes = pd.DataFrame({ #the order is TP1 thru TP8
    'Distance': [13, 23, 41, 50, 10.15, 14.6, 31.4, 56.6],
    'Elevation': [2722.652, 2723.389, 2724.88, 2725.338, 2733.665, 2733.998, 2735.669, 2738.474]  
})

# %%
# Plot the downstream reach
fig, ax = plt.subplots(figsize=(20, 6))
fig.patch.set_facecolor('white')  # set the figure's facecolor to white
ax.plot(down_reach.iloc[:, 0], down_reach.iloc[:, 1], label='Thalweg', color = 'black')


# add in groundwater wells 
# GW1
#plt.vlines(wells.iloc[0,0], wells.iloc[0,1]-1.20, wells.iloc[0,1], colors='brown', linewidth=3, label='Groundwater Wells')
#plt.text(wells.iloc[0,0], wells.iloc[0,1], 'GW1', ha='center', va='bottom')
# GW3
#plt.vlines(wells.iloc[2,0], wells.iloc[2,1]-1.20, wells.iloc[2,1], colors='brown', linewidth=3)
#plt.text(wells.iloc[2,0], wells.iloc[2,1], 'GW3', ha='center', va='bottom')

# add in groundwater wells 
# GW2
plt.vlines(wells.iloc[1,0], wells.iloc[1,1]-1.20, wells.iloc[1,1], colors='brown', linewidth=3, label='Groundwater Wells')
plt.text(wells.iloc[1,0], wells.iloc[1,1], 'GW2', ha='center', va='bottom')
# GW4
plt.vlines(wells.iloc[3,0], wells.iloc[3,1]-1.20, wells.iloc[3,1], colors='brown', linewidth=3)
plt.text(wells.iloc[3,0], wells.iloc[3,1], 'GW4', ha='center', va='bottom')


# add in piezomenters/stilling wells
# P1
plt.vlines(piezometers.iloc[0,0], piezometers.iloc[0,1]-0.5, piezometers.iloc[0,1], colors='green', linewidth=3, label='Piezometers')
plt.text(piezometers.iloc[0,0], piezometers.iloc[0,1], 'P1', ha='center', va='bottom')
# P
plt.vlines(piezometers.iloc[1,0], piezometers.iloc[1,1]-0.5, piezometers.iloc[1,1], colors='green', linewidth=3)
plt.text(piezometers.iloc[1,0], piezometers.iloc[1,1], 'P2', ha='center', va='bottom')
# P3
plt.vlines(piezometers.iloc[2,0], piezometers.iloc[2,1]-0.5, piezometers.iloc[2,1], colors='green', linewidth=3)
plt.text(piezometers.iloc[2,0], piezometers.iloc[2,1], 'P3', ha='center', va='bottom')

# add in temperature probes
# TP1
plt.vlines(temprobes.iloc[0,0], temprobes.iloc[0,1]-1, temprobes.iloc[0,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[0,0], temprobes.iloc[0,1], 'TP1', ha='center', va='bottom')
# TP2
plt.vlines(temprobes.iloc[1,0], temprobes.iloc[1,1]-1, temprobes.iloc[1,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[1,0], temprobes.iloc[1,1], 'TP2', ha='center', va='bottom')
# TP3
plt.vlines(temprobes.iloc[2,0], temprobes.iloc[2,1]-1, temprobes.iloc[2,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[2,0], temprobes.iloc[2,1], 'TP3', ha='center', va='bottom')

# Set the limits of the y-axis
ax.set_ylim(2721, 2725.5)

######## plotting the groundwater levels ########
gw_data = GW24_SM23
gw_data[gw_data.columns[0]] = pd.to_datetime(gw_data[gw_data.columns[0]]) # convert the first column to datetime
gw_data = gw_data.set_index(gw_data.columns[0]) # set the first column as the index

############### here is where you can change the time points ###############
start_point = gw_data.index[0] 
peak1_point = gw_data['8.5'].idxmax()
peak2_point = gw_data['29.5'].idxmax()
end_point = gw_data.index[-1]
###########################################################################

distances = pd.to_numeric(gw_data.columns[1:], errors='coerce')  # Skip the first column 'distance'
start_time_slice = gw_data.loc[start_point, :].values[1:]  # Skip the first column 'time'
peak1_time_slice = gw_data.loc[peak1_point, :].values[1:]  # Skip the first column 'time'
peak2_time_slice = gw_data.loc[peak2_point, :].values[1:]  # Skip the first column 'time'
end_time_slice = gw_data.loc[end_point, :].values[1:]  # Skip the first column 'time'

# Create a new DataFrame
df_plot = pd.DataFrame({
    'Distance': distances,
    'Start-Elevation': start_time_slice,
    'Peak1-Elevation': peak1_time_slice,
    'Peak2-Elevation': peak2_time_slice,
    'End-Elevation': end_time_slice
})

# plot the groundwater level against distance
ax.plot(distances, start_time_slice, color='cyan', linewidth=0.5, label=f'GW elevations at {start_point}')
ax.plot(distances, peak1_time_slice, color='orchid', linewidth=0.5, label=f'GW elevations at {peak1_point} (GW2 peak)')
ax.plot(distances, peak2_time_slice, color='tomato', linewidth=0.5, label=f'GW elevations at {peak2_point} (GW4 peak)')
ax.plot(distances, end_time_slice, color='darkblue', linewidth=0.5, label=f'GW elevations at {end_point}')

# Add labels and title
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Downstream Right Bank Groundwater Elevations')
ax.legend()

plt.savefig('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/Plots/DOWN_RIGHT_SM23.png')
# Show the plot
plt.show()

# %%
# Plot the downstream reach
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(up_reach.iloc[:, 0], up_reach.iloc[:, 1], label='Thalweg', color = 'black')

# add in groundwater wells 
# GW7
plt.vlines(wells.iloc[5,0], wells.iloc[5,1]-1.20, wells.iloc[5,1], colors='brown', linewidth=3, label='Groundwater Wells')
plt.text(wells.iloc[5,0], wells.iloc[5,1], 'GW6', ha='center', va='bottom')
# GW9
plt.vlines(wells.iloc[7,0], wells.iloc[7,1]-1.20, wells.iloc[7,1], colors='brown', linewidth=3)
plt.text(wells.iloc[7,0], wells.iloc[7,1], 'GW8', ha='center', va='bottom')

# add in piezomenters/stilling wells
# P4
plt.vlines(piezometers.iloc[3,0], piezometers.iloc[3,1]-0.5, piezometers.iloc[3,1], colors='green', linewidth=3, label='Piezometers')
plt.text(piezometers.iloc[3,0], piezometers.iloc[3,1], 'P4', ha='center', va='bottom')
# P5
plt.vlines(piezometers.iloc[4,0], piezometers.iloc[4,1]-0.5, piezometers.iloc[4,1], colors='green', linewidth=3)
plt.text(piezometers.iloc[4,0], piezometers.iloc[4,1], 'P5', ha='center', va='bottom')
# P6
plt.vlines(piezometers.iloc[5,0], piezometers.iloc[5,1]-0.5, piezometers.iloc[5,1], colors='green', linewidth=3)
plt.text(piezometers.iloc[5,0], piezometers.iloc[5,1], 'P6', ha='center', va='bottom')

# add in temperature probes
# TP5
plt.vlines(temprobes.iloc[4,0], temprobes.iloc[4,1]-1, temprobes.iloc[4,1], colors='orange', linewidth=3, label='Temperature Probes')
plt.text(temprobes.iloc[4,0], temprobes.iloc[4,1], 'TP5', ha='center', va='bottom')
# TP6
plt.vlines(temprobes.iloc[5,0], temprobes.iloc[5,1]-1, temprobes.iloc[5,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[5,0], temprobes.iloc[5,1], 'TP6', ha='center', va='bottom')
# TP7
plt.vlines(temprobes.iloc[6,0], temprobes.iloc[6,1]-1, temprobes.iloc[6,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[6,0], temprobes.iloc[6,1], 'TP7', ha='center', va='bottom')
# TP8
plt.vlines(temprobes.iloc[7,0], temprobes.iloc[7,1]-1, temprobes.iloc[7,1], colors='orange', linewidth=3)
plt.text(temprobes.iloc[7,0], temprobes.iloc[7,1], 'TP8', ha='center', va='bottom')

######## plotting the groundwater levels ########
gw_data = GW68_SP23
gw_data[gw_data.columns[0]] = pd.to_datetime(gw_data[gw_data.columns[0]]) # convert the first column to datetime
gw_data = gw_data.set_index(gw_data.columns[0]) # set the first column as the index

############### here is where you can change the time points ###############
start_point = gw_data.index[0] 
peak1_point = gw_data['18'].idxmax()
peak2_point = gw_data['36.2'].idxmax()
end_point = gw_data.index[-1]
###########################################################################

distances = pd.to_numeric(gw_data.columns[1:], errors='coerce')  # Skip the first column 'distance'
start_time_slice = gw_data.loc[start_point, :].values[1:]  # Skip the first column 'time'
peak1_time_slice = gw_data.loc[peak1_point, :].values[1:]  # Skip the first column 'time'
peak2_time_slice = gw_data.loc[peak2_point, :].values[1:]  # Skip the first column 'time'
end_time_slice = gw_data.loc[end_point, :].values[1:]  # Skip the first column 'time'

# Create a new DataFrame
df_plot = pd.DataFrame({
    'Distance': distances,
    'Start-Elevation': start_time_slice,
    'Peak1-Elevation': peak1_time_slice,
    'Peak2-Elevation': peak2_time_slice,
    'End-Elevation': end_time_slice
})

# plot the groundwater level against distance
ax.plot(distances, start_time_slice, color='cyan', linewidth=0.5, label=f'GW elevations at {start_point}')
ax.plot(distances, peak1_time_slice, color='orchid', linewidth=0.5, label=f'GW elevations at {peak1_point} (GW6 peak)')
ax.plot(distances, peak2_time_slice, color='tomato', linewidth=0.5, label=f'GW elevations at {peak2_point} (GW8 peak)')
ax.plot(distances, end_time_slice, color='darkblue', linewidth=0.5, label=f'GW elevations at {end_point}')

# Add labels and title
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Elevation (m)')
ax.set_title(f'Upstream Left Bank Groundwater Elevations')
ax.legend()

plt.savefig('C:/Users/nicol/Documents/GitHub/La_Jara/GW-Hyporheic/Plots/UP_LEFT_SP23.png')
# Show the plot
plt.show()

# %%
GW68_SP23[GW68_SP23.columns[0]] = pd.to_datetime(GW68_SP23[GW68_SP23.columns[0]])
GW68_SP23.set_index(GW68_SP23.columns[0], inplace=True)
GW68_SP23['2.6']# location of P4C
# Out:
# distance
# 2023-03-02 00:00:00    2732.626079
# 2023-03-02 00:15:00    2732.626838
# 2023-03-02 00:30:00    2732.632227
# 2023-03-02 00:45:00    2732.627247
# 2023-03-02 01:00:00    2732.630069
#                           ...
# 2023-06-20 22:30:00    2732.721033
# 2023-06-20 22:45:00    2732.722516
# 2023-06-20 23:00:00    2732.721035
# 2023-06-20 23:15:00    2732.720724
# 2023-06-20 23:30:00    2732.720063
# Name: 2.6, Length: 8697, dtype: float64

# %%
value = GW68_SP23.loc['2023-03-28 07:45:00', '2.6']
value
# Out:
# 2733.171776
