# %%
cd Documents/GitHub/La_Jara/Presentations/DOEPI_Poster/Storm2
# Out:
# C:\Users\nicol\Documents\GitHub\La_Jara\Presentations\DOEPI_Poster\Storm2

# %%
#Import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  

#Import Data
tp = pd.read_excel('st2_tp.xlsx')
sp = pd.read_excel('st2_sp.xlsx')
pp = pd.read_excel('st2_pp.xlsx')
turb = pd.read_csv('st2_sonde.csv')
ss = pd.read_excel('st2_ss.xlsx')

# %%
import matplotlib.collections as mcoll
import matplotlib.path as mpath

def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

def colorline(x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0), linewidth=3, alpha=1.0):
    """
    http://nbviewer.ipython.org/github/dpsanders/matplotlib-examples/blob/master/colorline.ipynb
    http://matplotlib.org/examples/pylab_examples/multicolored_line.html
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)
    
    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm, linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)

    return lc

# %% [markdown]
# ## PP

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('Oranges_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(pp['q']))
colorline(pp['q'], pp['PP'], z, cmap=plt.get_cmap('Oranges_r'), linewidth=4)
sc =ax1.scatter(pp['q'], pp['PP'], c=range(len(pp['q'])), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(4.2,0.52,'Sample #', fontsize=10)
ax1.set_title('PP Storm 2', fontsize=14)
ax1.set_ylabel("Particulate Phosphorus (\u03bcmol/L)", fontsize=12)
ax1.set_xlabel("Discharge (cfs)", fontsize=12)

plt.savefig("ST2_PP.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_10652\575690427.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ## SRP

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('Oranges_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(sp['q']))
colorline(sp['q'], sp['SRP'], z, cmap=plt.get_cmap('Oranges_r'), linewidth=4)
sc =ax1.scatter(sp['q'], sp['SRP'], c=range(len(sp['q'])), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(4.2,0.078,'Sample #', fontsize=10)
ax1.set_title('SRP Storm 2', fontsize=14)
ax1.set_ylabel("Soluble Reactive Phosphorus (mg/L)", fontsize=12)
ax1.set_xlabel("Discharge (cfs)", fontsize=12)

plt.savefig("ST2_SP.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_10652\283389781.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ## TP

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
plt.grid(False)
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('Oranges_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(tp['q']))
colorline(tp['q'], tp['TP'], z, cmap=plt.get_cmap('Oranges_r'), linewidth=4)
sc =ax1.scatter(tp['q'], tp['TP'], c=range(len(tp['q'])), cmap=cm, zorder=100)

plt.colorbar(sc, ax=ax1)
plt.text(4.2,0.108,'Sample #', fontsize=10)
ax1.set_title('TP Storm 2', fontsize=14)
ax1.set_ylabel("Total Phosphorus (mg/L)", fontsize=12)
ax1.set_xlabel("Discharge (cfs)", fontsize=12)

plt.savefig("ST2_TP.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_10652\1295211611.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ## SS

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
plt.grid(False)
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('Oranges_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(ss['q']))
colorline(ss['q'], ss['SS'], z, cmap=plt.get_cmap('Oranges_r'), linewidth=4)
sc =ax1.scatter(ss['q'], ss['SS'], c=range(len(ss['q'])), cmap=cm, zorder=100)

plt.colorbar(sc, ax=ax1)
plt.text(4.2,228,'Sample #', fontsize=10)
ax1.set_title('SS Storm 2', fontsize=14)
ax1.set_ylabel("Suspended Sediment (mg/L)", fontsize=12)
ax1.set_xlabel("Discharge (cfs)", fontsize=12)

plt.savefig("ST2_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_10652\512627078.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ## Turbidity

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
plt.grid(False)
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('Oranges_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(turb['q']))
colorline(turb['q'], turb['Turbidity'], z, cmap=plt.get_cmap('Oranges_r'), linewidth=4)
sc =ax1.scatter(turb['q'], turb['Turbidity'], c=range(len(turb['q'])), cmap=cm, zorder=100)

plt.colorbar(sc, ax=ax1)
plt.text(4.3,24.2,'Sample #', fontsize=10)
ax1.set_title('Turbidity Storm 2', fontsize=14)
ax1.set_ylabel("Turbidity (FNU)", fontsize=12)
ax1.set_xlabel("Discharge (cfs)", fontsize=12)

plt.savefig("ST2_turb.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_10652\2085789683.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)
