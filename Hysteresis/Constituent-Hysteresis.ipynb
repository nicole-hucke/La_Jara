# %%
cd Documents/GitHub/La_Jara/Hysteresis
# Out:
# C:\Users\nicol\Documents\GitHub\La_Jara\Hysteresis

# %%
#Import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  

#Import Data
storm1 = pd.read_csv('Storm1_2022.csv')
storm2 = pd.read_csv('Storm2_2022.csv')

# %%
storm2
# Out:
#              Time      SS  Botttle  Depth    DOC
# 0  8/8/2022 13:43    0.00        1  7.000  3.359
# 1  8/8/2022 13:58    0.00        2  7.583  3.424
# 2  8/8/2022 14:28  204.03        4  8.867  5.279
# 3  8/8/2022 14:43  105.77        5  8.983  7.207
# 4  8/8/2022 15:23   68.83        7  7.875  8.410
# 5  8/8/2022 16:13   36.65       11  7.584  2.705
# 6  8/8/2022 16:28   25.92       12  7.409  8.421
# 7  8/8/2022 16:58   19.05       14  7.409  8.183
# 8  8/8/2022 17:28   18.36       16  7.408  2.742
# 9  8/8/2022 18:13    0.00       19  7.350  8.085

# %%
# Storm 1: Suspended Sediment Hysteresis
plt.plot(storm1['Depth'], storm1['SS'], zorder=0)
cm = plt.cm.get_cmap('viridis')
sc = plt.scatter(storm1['Depth'], storm1['SS'], c=range(22), cmap=cm, zorder=100)

plt.colorbar(sc)
plt.text(7.7,225,'Sample #', fontsize=9)

plt.xlabel("Depth (cmH2O)")
plt.ylabel("Suspended Sediment (mg/L)")
plt.title("Storm 1 Summer 2022 SS Hysteresis")

plt.grid()
sns.set_style("whitegrid")
plt.savefig("Storm1_SS_Hysteresis.png", dpi=300)
plt.show()

# %%
# Storm 2: Suspended Sediment Hysteresis
plt.plot(storm2['Depth'], storm2['SS'], zorder=0)
cm = plt.cm.get_cmap('viridis')
sc = plt.scatter(storm2['Depth'], storm2['SS'], c=range(10), cmap=cm, zorder=100)

plt.colorbar(sc)
plt.text(9.15,223,'Sample #', fontsize=9)

plt.xlabel("Depth (cmH2O)")
plt.ylabel("Suspended Sediment (mg/L)")
plt.title("Storm 2 Summer 2022 SS Hysteresis")

plt.grid()
sns.set_style("whitegrid")
plt.savefig("Storm2_SS_Hysteresis.png", dpi=300)
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\2611912520.py:6: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc)

# %%
# Storm 1: DOC Hysteresis
plt.plot(storm1['DOCdepth'], storm1['DOC'], zorder=0)
cm = plt.cm.get_cmap('viridis')
sc = plt.scatter(storm1['DOCdepth'], storm1['DOC'], c=range(22), cmap=cm, zorder=100)

plt.colorbar(sc)
plt.text(7.7,9.3,'Sample #', fontsize=9)

plt.xlabel("Depth (cmH2O)")
plt.ylabel("DOC (mg/L)")
plt.title("Storm 1 Summer 2022 DOC Hysteresis")

plt.grid()
sns.set_style("whitegrid")
plt.savefig("Storm1_DOC_Hysteresis.png", dpi=300)
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\859763391.py:6: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc)

# %%
# Storm 2: Suspended Sediment Hysteresis
plt.plot(storm2['Depth'], storm2['DOC'], zorder=0)
cm = plt.cm.get_cmap('viridis')
sc = plt.scatter(storm2['Depth'], storm2['DOC'], c=range(10), cmap=cm, zorder=100)

plt.colorbar(sc)
plt.text(9.15,9,'Sample #', fontsize=9)

plt.xlabel("Depth (cmH2O)")
plt.ylabel("DOC (mg/L)")
plt.title("Storm 2 Summer 2022 DOC Hysteresis")

plt.grid()
sns.set_style("whitegrid")
plt.savefig("Storm2_DOC_Hysteresis.png", dpi=300)
plt.show()
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\1512733453.py:6: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc)

# %% [markdown]
# ## Plots for my AGU poster

# %%
import matplotlib.collections as mcoll
import matplotlib.path as mpath

def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

def colorline(x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0), linewidth=3, alpha=1.0):
    """
    http://nbviewer.ipython.org/github/dpsanders/matplotlib-examples/blob/master/colorline.ipynb
    http://matplotlib.org/examples/pylab_examples/multicolored_line.html
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)
    
    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm, linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)

    return lc

font = {'fontname':'Tenorite'}

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(storm1['Depth']))
colorline(storm1['Depth'], storm1['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(storm1['Depth'], storm1['SS'], c=range(22), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(7.6,224,'Sample #', fontsize=10, **font)
ax1.set_title('TSS Storm 1-2022', fontsize=14, **font)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("SS1_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\2187840414.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
fig, (ax1) = plt.subplots(figsize=(4,3))
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(storm2['Depth']))
colorline(storm2['Depth'], storm2['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(storm2['Depth'], storm2['SS'], c=range(10), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(9.1,221,'Sample #', fontsize=10, **font)
ax1.set_title('TSS Storm 2-2022', fontsize=14, **font)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("SS2_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\4138979577.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
up = pd.read_csv('Summer2021_Upstream_Constituents.csv')

fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)


z = np.linspace(0, 1, len(up['q']))
colorline(up['q'], up['SS (mg/L)'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(up['q'], up['SS (mg/L)'], c=range(6), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(4.1,435,'Sample #', fontsize=10, **font)
ax1.set_title('TSS Storm 1-2021', fontsize=14, **font)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12, **font)
ax1.set_xlabel("Discharge (cfs)", fontsize=12, **font)

plt.savefig("SS1_SM21_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\3557556065.py:13: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
#Import Data
depth = pd.read_csv('Piezo2A-Summer2022.csv').iloc[2576:2625]
sonde = pd.read_csv('Sonde_Summer2022_Storm2.csv').iloc[0:69]
#Putting everything in one df
sonde.rename(columns={'datetime': 'Time'}, inplace=True)
df = pd.merge(depth, sonde, on='Time', how='left')
#Converting into a date-time kind of variable

fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(df['Pressure[cmH2O]']))
colorline(df['Pressure[cmH2O]'], df['Turbidity'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(df['Pressure[cmH2O]'], df['Turbidity'], c=range(49), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(9.1,24.5,'Sample #', fontsize=10, **font)
ax1.set_title('Turbidity Storm 2-2022', fontsize=14, **font)
ax1.set_ylabel("Turbidity (FNU)", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("turb2_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\3273816938.py:18: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
#Import Data
depth = pd.read_csv('Piezo2A-Summer2022.csv').iloc[2100:2145]
sonde = pd.read_csv('Sonde_Summer2022_Storm1.csv').iloc[0:69]
#Putting everything in one df
sonde.rename(columns={'datetime': 'Time'}, inplace=True)
df = pd.merge(depth, sonde, on='Time', how='left')
#Converting into a date-time kind of variable

fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(df['Pressure[cmH2O]']))
colorline(df['Pressure[cmH2O]'], df['Turbidity'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(df['Pressure[cmH2O]'], df['Turbidity'], c=range(45), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(7.7,24,'Sample #', fontsize=10, **font)
ax1.set_title('Turbidity Storm 1-2022', fontsize=14, **font)
ax1.set_ylabel("Turbidity (FNU)", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("turb1_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\1559627086.py:18: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
#Import Data
depth = pd.read_csv('Piezo2A-Summer2022.csv').iloc[2576:2625]
sonde = pd.read_csv('Sonde_Summer2022_Storm2.csv').iloc[0:69]
#Putting everything in one df
sonde.rename(columns={'datetime': 'Time'}, inplace=True)
df = pd.merge(depth, sonde, on='Time', how='left')
#Converting into a date-time kind of variable

fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(df['Pressure[cmH2O]']))
colorline(df['Pressure[cmH2O]'], df['fDOM'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(df['Pressure[cmH2O]'], df['fDOM'], c=range(49), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(9.1,80.2,'Sample #', fontsize=10, **font)
ax1.set_title('fDOM Storm 2-2022', fontsize=14, **font)
ax1.set_ylabel("fDOM (QSU)", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("fDOM2_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\2304375297.py:18: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
#Import Data
depth = pd.read_csv('Piezo2A-Summer2022.csv').iloc[2100:2145]
sonde = pd.read_csv('Sonde_Summer2022_Storm1.csv').iloc[0:69]
#Putting everything in one df
sonde.rename(columns={'datetime': 'Time'}, inplace=True)
df = pd.merge(depth, sonde, on='Time', how='left')
#Converting into a date-time kind of variable

fig, (ax1) = plt.subplots(figsize=(4,3))
#sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(df['Pressure[cmH2O]']))
colorline(df['Pressure[cmH2O]'], df['fDOM'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(df['Pressure[cmH2O]'], df['fDOM'], c=range(45), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(7.6,81,'Sample #', fontsize=10, **font)
ax1.set_title('fDOM Storm 1-2022', fontsize=14, **font)
ax1.set_ylabel("fDOM (QSU))", fontsize=12, **font)
ax1.set_xlabel("Water Depth (cm)", fontsize=12, **font)

plt.savefig("fDOM1_SM22_Hysteresis.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_8116\3400048034.py:18: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)
