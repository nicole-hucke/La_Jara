# %%
cd Documents/GitHub/La_Jara/Hysteresis/Experiments-Summer2022
# Out:
# C:\Users\nicol\Documents\GitHub\La_Jara\Hysteresis\Experiments-Summer2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns  

#Import Data
exp1 = pd.read_csv('Experiment1_2022.csv')
exp2 = pd.read_csv('Experiment2_2022.csv')
exp3 = pd.read_csv('Experiment3_2022.csv')
exp4 = pd.read_csv('Experiment4_2022.csv')
exp5 = pd.read_csv('Experiment5_2022.csv')
exp6 = pd.read_csv('Experiment6_2022.csv')
exp8 = pd.read_csv('Experiment8_2022.csv')

import matplotlib.collections as mcoll
import matplotlib.path as mpath

def make_segments(x, y):
    """
    Create list of line segments from x and y coordinates, in the correct format
    for LineCollection: an array of the form numlines x (points per line) x 2 (x
    and y) array
    """

    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    return segments

def colorline(x, y, z=None, cmap=plt.get_cmap('copper'), norm=plt.Normalize(0.0, 1.0), linewidth=3, alpha=1.0):
    """
    Plot a colored line with coordinates x and y
    Optionally specify colors in the array z
    Optionally specify a colormap, a norm function and a line width
    """

    # Default colors equally spaced on [0,1]:
    if z is None:
        z = np.linspace(0.0, 1.0, len(x))

    # Special case if a single number:
    if not hasattr(z, "__iter__"):  # to check for numerical input -- this is a hack
        z = np.array([z])

    z = np.asarray(z)
    
    segments = make_segments(x, y)
    lc = mcoll.LineCollection(segments, array=z, cmap=cmap, norm=norm, linewidth=linewidth, alpha=alpha)

    ax = plt.gca()
    ax.add_collection(lc)

    return lc

# %% [markdown]
# ### Experiment 1

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp1['Depth']))
colorline(exp1['Depth'], exp1['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp1['Depth'], exp1['SS'], c=range(15), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(23.5,379,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 1 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP1_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\2639259256.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp1['Depth']))
colorline(exp1['Depth'], exp1['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp1['Depth'], exp1['DOC'], c=range(15), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(23.5,2.67,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 1 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP1_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\3849124579.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 2

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp2['Depth']))
colorline(exp2['Depth'], exp2['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp2['Depth'], exp2['SS'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22.5,250,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 2 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP2_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\406923996.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp2['Depth']))
colorline(exp2['Depth'], exp2['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp2['Depth'], exp2['DOC'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22.5,3.04,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 2 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP2_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\4164463708.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 3

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp3['Depth']))
colorline(exp3['Depth'], exp3['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp3['Depth'], exp3['SS'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22.5,300,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 3 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP3_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\2459111950.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp3['Depth']))
colorline(exp3['Depth'], exp3['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp3['Depth'], exp3['DOC'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22.5,2.915,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 3 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP3_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\1662841273.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 4

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp4['Depth']))
colorline(exp4['Depth'], exp4['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp4['Depth'], exp4['SS'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22.5,550,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 4 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP4_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\3385830520.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp4['Depth']))
colorline(exp4['Depth'], exp4['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp4['Depth'], exp4['DOC'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(22,2.325,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 4 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP4_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\271091479.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 5

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp5['Depth']))
colorline(exp5['Depth'], exp5['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp5['Depth'], exp5['SS'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(24,465,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 5 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP5_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\1525408738.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp5['Depth']))
colorline(exp5['Depth'], exp5['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp5['Depth'], exp5['DOC'], c=range(16), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(24,2.915,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 5 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP5_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\2628536955.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 6

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp6['Depth']))
colorline(exp6['Depth'], exp6['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp6['Depth'], exp6['SS'], c=range(11), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(10.7,95,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 6 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP6_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\695405471.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp6['Depth']))
colorline(exp6['Depth'], exp6['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp6['Depth'], exp6['DOC'], c=range(11), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(10.72,3.72,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 6 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP6_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\3845997325.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %% [markdown]
# ### Experiment 8

# %%
### SUSPENDED SEDIMENT 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp8['Depth']))
colorline(exp8['Depth'], exp8['SS'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp8['Depth'], exp8['SS'], c=range(11), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(9.5,340,'Sample #', fontsize=10)
ax1.set_title('TSS Experiment 8 - 2022', fontsize=14)
ax1.set_ylabel("Total Suspended Solids (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP8_SS.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\2957583431.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
### DOC 

fig, (ax1) = plt.subplots(figsize=(4,3))
sns.set_style('darkgrid')
cm = plt.cm.get_cmap('YlGnBu_r')
fig.tight_layout(h_pad=100)

z = np.linspace(0, 1, len(exp8['Depth']))
colorline(exp8['Depth'], exp8['DOC'], z, cmap=plt.get_cmap('YlGnBu_r'), linewidth=4)
sc =ax1.scatter(exp8['Depth'], exp8['DOC'], c=range(11), cmap=cm, zorder=100)
plt.grid(False)
plt.colorbar(sc, ax=ax1)
plt.text(9.5,3.2,'Sample #', fontsize=10)
ax1.set_title('DOC Experiment 8 - 2022', fontsize=14)
ax1.set_ylabel("DOC (mg/L)", fontsize=12)
ax1.set_xlabel("Water Depth (cmH20)", fontsize=12)

plt.savefig("EXP8_DOC.png", bbox_inches = 'tight', dpi=1000)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_24836\2042137667.py:12: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sc, ax=ax1)

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp1['Time'] = pd.to_datetime(exp1['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp1['Time'], exp1['Depth'], color=color1, linestyle="-",label='Water Depth')
ax1.tick_params(axis='y', labelcolor=color1)
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp1['Time'], exp1['SS'], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [0,1, 2, 3, 4, 5, 8, 11]
ax2.plot(exp1.loc[samples_to_plot, 'Time'], exp1.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 1 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp1.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp2['Time'] = pd.to_datetime(exp2['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp2['Time'], exp2['Depth'], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp2['Time'], exp2['SS'], "o-", color=color2,label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [0,1, 2, 3, 4, 5, 6, 9, 11, 14]
ax2.plot(exp2.loc[samples_to_plot, 'Time'], exp2.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 2 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp2.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp3['Time'] = pd.to_datetime(exp3['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp3['Time'], exp3['Depth'], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp3['Time'], exp3['SS'], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [0, 1, 2, 3, 5, 6, 7, 8, 11]
ax2.plot(exp3.loc[samples_to_plot, 'Time'], exp3.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 3 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp3.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp4['Time'] = pd.to_datetime(exp4['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp4['Time'][1:], exp4['Depth'][1:], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp4['Time'][1:], exp4['SS'][1:], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [1, 2, 3, 4, 5, 7, 9, 11]
ax2.plot(exp4.loc[samples_to_plot, 'Time'], exp4.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 4 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp4.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp4['Time'] = pd.to_datetime(exp4['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp4['Time'], exp4['Depth'], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'tab:red'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp4['Time'], exp4['SS'], "o-", color=color2)
ax2.tick_params(axis='y', labelcolor=color2)

plt.title("Experiment 4 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")

fig.tight_layout()
plt.savefig("exp4.png", dpi=300)
plt.show()

# %%
exp5
# Out:
#     Bottle number                Time   Depth      SS    DOC
# 0             1.0 2023-08-21 11:14:20   3.558   90.43  2.631
# 1             2.0 2023-08-21 11:18:35   7.525  426.28  2.581
# 2             3.0 2023-08-21 11:18:40  12.133  258.72  2.563
# 3             4.0 2023-08-21 11:18:45  21.991  227.15  2.662
# 4             5.0 2023-08-21 11:18:50  23.275  176.59  2.696
# 5             6.0 2023-08-21 11:19:00  16.100  181.06  2.699
# 6             7.0 2023-08-21 11:19:10  13.708  157.00  2.742
# 7             8.0 2023-08-21 11:19:20  12.483  134.23  2.761
# 8             9.0 2023-08-21 11:19:30  11.375   88.31  2.821
# 9            10.0 2023-08-21 11:19:40  10.558   88.72  2.783
# 10           11.0 2023-08-21 11:19:50  10.850   71.86  2.756
# 11           12.0 2023-08-21 11:20:00  10.850   59.21  2.883
# 12           13.0 2023-08-21 11:20:10  10.383   51.52  2.840
# 13            NaN                 NaT     NaN     NaN    NaN
# ...

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp5['Time'] = pd.to_datetime(exp5['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time', )
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp5['Time'][1:], exp5['Depth'][1:], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)

ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp5['Time'][1:], exp5['SS'][1:], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [1, 2, 3, 4, 5, 7, 9, 11]
ax2.plot(exp5.loc[samples_to_plot, 'Time'], exp5.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 5 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp5.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp6['Time'] = pd.to_datetime(exp6['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time', )
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp6['Time'][1:], exp6['Depth'][1:], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)

ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp6['Time'][1:], exp6['SS'][1:], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [2, 3, 4, 5, 7, 9]
ax2.plot(exp6.loc[samples_to_plot, 'Time'], exp6.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 6 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp6.png", dpi=300)
plt.show()

# %%
fig, ax1 = plt.subplots()

# Convert the 'Time' column to datetime format
exp8['Time'] = pd.to_datetime(exp8['Time'])

color1 = 'tab:blue'
ax1.set_xlabel('Time', )
ax1.set_ylabel('Depth (cmH2O)', color=color1)
ax1.plot(exp8['Time'], exp8['Depth'], color=color1, linestyle="-")
ax1.tick_params(axis='y', labelcolor=color1)

ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xticks(rotation=40)

ax2 = ax1.twinx()  # initiate a second axes that shares the same x-axis

color2 = 'black'
ax2.set_ylabel('Suspended Sediment', color=color2)  # we already handled the x-label with ax1
ax2.plot(exp8['Time'], exp8['SS'], "o-", color=color2, label='SS Concentration')
ax2.tick_params(axis='y', labelcolor=color2)

# Plot select samples with green color
samples_to_plot = [1 ,2, 3, 4, 6, 7, 9]
ax2.plot(exp8.loc[samples_to_plot, 'Time'], exp8.loc[samples_to_plot, 'SS'],'o', color='red', label='Selected Samples for POC')

plt.title("Experiment 8 hydrograph and SS")
plt.grid()
sns.set_style("whitegrid")
ax2.legend()

fig.tight_layout()
plt.savefig("exp8.png", dpi=300)
plt.show()
